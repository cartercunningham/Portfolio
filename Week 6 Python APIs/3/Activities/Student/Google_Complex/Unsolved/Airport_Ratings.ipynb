# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Import API
from config import gkey

# %%
# Import cities file into the cities_pd DataFrame
cities_df = pd.read_csv("../Resources/Cities.csv")
cities_df.head()
# Out:
#             City         State
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania

# %%
# Add columns for .
# Hint: Be sure to specify "" as the initial value for each column.
cities_df["lat"] = ""
cities_df["lng"] = ""
cities_df["airport name"] = ""
cities_df["airport address"] = ""
cities_df["airport rating"] = ""
cities_df.head()
# Out:
#             City         State lat lng airport name airport address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   airport rating
# 0
# 1
# 2
# 3
# 4

# %%
# Loop through the cities_pd and get the lat/long for each city
# Hint: `requests.get(target_url).json()`
# Hint: `for index, row in cities_pd.iterrows():`
# Hint: `cities_pd.loc`

# create a params dict that will be updated with new city each iteration# creat 
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    city = row['City']
    state = row['State']

    # update address key value
    params['address'] = f"{city},{state}"

    # make request
    cities_lat_lng = requests.get(base_url, params=params)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    # print(cities_lat_lng.url)
    
    # convert to json
    cities_lat_lng = cities_lat_lng.json()

    cities_df.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    cities_df.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
cities_df.head()
# Out:
# AIzaSyAnNzdonhbEkTAyV4AGWfIsRCZHidkY0sg
#             City         State lat lng airport name airport address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   airport rating        Lat         Lng
# 0                 40.712775  -74.005973
# 1                 34.052234 -118.243685
# 2                 41.878114  -87.629798
# 3                 29.760427  -95.369803
# 4                 39.952584  -75.165222

# %%
## params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "airport",
    "keyword": "international airport",
    "key": gkey
}

# Use the lat/lng we recovered to identify airports
for index, row in cities_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
#     print the name_address url, avoid doing for public github repos in order to avoid exposing key
#     print(name_address.url)

    # convert to json
    name_address = name_address.json()
    # print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_df.loc[index, "Airport Name"] = name_address["results"][0]["name"]
        cities_df.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        cities_df.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

cities_df
# Out:
#                City                 State lat lng airport name  \
# 0     New York City              New York
# 1       Los Angeles            California
# 2           Chicago              Illinois
# 3           Houston                 Texas
# 4      Philadelphia          Pennsylvania
# 5           Phoenix               Arizona
# 6       San Antonio                 Texas
# 7         San Diego            California
# 8            Dallas                 Texas
# 9          San Jose            California
# 10           Austin                 Texas
# 11     Jacksonville               Florida
# 12    San Francisco            California
# 13     Indianapolis               Indiana
# 14         Columbus                  Ohio
# 15       Fort Worth                 Texas
# 16        Charlotte        North Carolina
# 17          Seattle            Washington
# 18           Denver              Colorado
# 19          El Paso                 Texas
# 20          Detroit              Michigan
# 21       Washington  District of Columbia
# 22           Boston         Massachusetts
# 23          Memphis             Tennessee
# 24        Nashville             Tennessee
# 25         Portland                Oregon
# 26    Oklahoma City              Oklahoma
# 27        Las Vegas                Nevada
# 28        Baltimore              Maryland
# 29       Louisville              Kentucky
# ..              ...                   ...  ..  ..          ...
# 70           Toledo                  Ohio
# 71          Lincoln              Nebraska
# 72          Orlando               Florida
# 73      Chula Vista            California
# 74      Jersey City            New Jersey
# 75         Chandler               Arizona
# 76       Fort Wayne               Indiana
# 77          Buffalo              New York
# 78           Durham        North Carolina
# 79   St. Petersburg               Florida
# 80           Irvine            California
# 81           Laredo                 Texas
# 82          Lubbock                 Texas
# 83          Madison             Wisconsin
# 84          Gilbert               Arizona
# 85          Norfolk              Virginia
# 86             Reno                Nevada
# 87    Winston-Salem        North Carolina
# 88         Glendale               Arizona
# 89          Hialeah               Florida
# 90          Garland                 Texas
# 91       Scottsdale               Arizona
# 92           Irving                 Texas
# 93       Chesapeake              Virginia
# 94  North Las Vegas                Nevada
# 95          Fremont            California
# 96      Baton Rouge             Louisiana
# 97         Richmond              Virginia
# 98            Boise                 Idaho
# 99   San Bernardino            California
#
#    airport address airport rating        Lat         Lng  \
# 0                                  40.712775  -74.005973
# 1                                  34.052234 -118.243685
# 2                                  41.878114  -87.629798
# 3                                  29.760427  -95.369803
# 4                                  39.952584  -75.165222
# 5                                  33.448377 -112.074037
# 6                                  29.424122  -98.493628
# 7                                  32.715738 -117.161084
# 8                                  32.776664  -96.796988
# 9                                  37.338208 -121.886329
# 10                                 30.267153  -97.743061
# 11                                 30.332184  -81.655651
# 12                                 37.774929 -122.419415
# 13                                 39.768403  -86.158068
# 14                                 39.961176  -82.998794
# 15                                 32.755488  -97.330766
# 16                                 35.227087  -80.843127
# 17                                 47.606209 -122.332071
# 18                                 39.739236 -104.990251
# 19                                 31.761878 -106.485022
# 20                                 42.331427  -83.045754
# 21                                 38.907192  -77.036871
# 22                                 42.360082  -71.058880
# 23                                 35.149534  -90.048980
# 24                                 36.162664  -86.781602
# 25                                 45.512231 -122.658719
# 26                                 35.467560  -97.516428
# 27                                 36.169941 -115.139830
# 28                                 39.290385  -76.612189
# 29                                 38.252665  -85.758456
# ..             ...            ...        ...         ...
# 70                                 41.652805  -83.537867
# 71                                 40.813616  -96.702596
# 72                                 28.538335  -81.379237
# 73                                 32.640054 -117.084196
# 74                                 40.728157  -74.077642
# 75                                 33.306160 -111.841250
# 76                                 41.079273  -85.139351
# 77                                 42.886447  -78.878369
# 78                                 35.994033  -78.898619
# 79                                 27.767601  -82.640291
# 80                                 33.684567 -117.826505
# 81                                 27.503561  -99.507552
# 82                                 33.577863 -101.855166
# 83                                 43.073052  -89.401230
# 84                                 33.352826 -111.789027
# 85                                 36.850769  -76.285873
# 86                                 39.529633 -119.813803
# 87                                 36.099860  -80.244216
# 88                                 33.538652 -112.185987
# 89                                 25.857596  -80.278106
# 90                                 32.912624  -96.638883
# 91                                 33.494170 -111.926052
# 92                                 32.814018  -96.948894
# 93                                 36.768209  -76.287493
# 94                                 36.198859 -115.117501
# 95                                 37.548270 -121.988572
# 96                                 30.451468  -91.187147
# 97                                 37.540725  -77.436048
# 98                                 43.615019 -116.202314
# 99                                 34.108345 -117.289765
#
#                                          Airport Name  \
# 0                Newark Liberty International Airport
# 1                   Los Angeles International Airport
# 17                 17801 International Blvd, Seattle             3.7
# 18                            8500 Peña Blvd, Denver             4.0
# 19                          6701 Convair Rd, El Paso             4.3
# 20                                           Detroit             4.1
# 21                            1 Saarinen Cir, Dulles             3.9
# 22                           1 Harborside Dr, Boston             3.9
# 23                       2491 Winchester Rd, Memphis             3.6
# 24                          1 Terminal Dr, Nashville             4.1
# 25                     7000 NE Airport Way, Portland             4.5
# 26                   7100 Terminal Dr, Oklahoma City             4.1
# 27                 5757 Wayne Newton Blvd, Las Vegas             4.0
# 28                                         Baltimore             4.0
# 29                       600 Terminal Dr, Louisville             4.0
# ..                                               ...             ...
# 70             13336 Gildersleeve St, South Rockwood             0.0
# 71             12617 Weeping Water Rd, Weeping Water             5.0
# 72                        1 Jeff Fuqua Blvd, Orlando             3.7
# 73                       3225 N Harbor Dr, San Diego             3.9
# 74                             3 Brewster Rd, Newark             3.2
# 75                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 76                    3801 W Ferguson Rd, Fort Wayne             3.7
# 77                          4200 Genesee St, Buffalo             4.2
# 78              2400 John Brantley Blvd, Morrisville             4.2
# 79                    4100 George J Bean Pkwy, Tampa             4.4
# 80                                           Ontario             4.2
# 81                     5210 Bob Bullock Loop, Laredo             4.0
# 82                5401 N Martin L King Blvd, Lubbock             3.8
# 83                    4000 International Ln, Madison             4.2
# 84                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 85                         2200 Norview Ave, Norfolk             3.7
# 86                             2001 E Plumb Ln, Reno             4.1
# 87                 1000 Ted Johnson Pkwy, Greensboro             4.4
# 88                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 89                           2100 NW 42nd Ave, Miami             3.7
# 90                     2400 Aviation Dr, DFW Airport             3.8
# 91                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 92                     2400 Aviation Dr, DFW Airport             3.8
# 93                         2200 Norview Ave, Norfolk             3.7
# 94                 5757 Wayne Newton Blvd, Las Vegas             4.0
# 95                             1 Airport Dr, Oakland             3.8
# 96               9430 Jackie Cochran Dr, Baton Rouge             3.9
# 97            1 Richard E Byrd Terminal Dr, Richmond             4.1
# 98                               County Rd 46, Boise             0.0
# 99                                           Ontario             4.2
#
# [100 rows x 12 columns]

# %%
# Save Data to csv


# Visualize to confirm airport data appears
cities_df
# Out:
#                City                 State lat lng airport name  \
# 0     New York City              New York
# 1       Los Angeles            California
# 2           Chicago              Illinois
# 3           Houston                 Texas
# 4      Philadelphia          Pennsylvania
# 5           Phoenix               Arizona
# 6       San Antonio                 Texas
# 7         San Diego            California
# 8            Dallas                 Texas
# 9          San Jose            California
# 10           Austin                 Texas
# 11     Jacksonville               Florida
# 12    San Francisco            California
# 13     Indianapolis               Indiana
# 14         Columbus                  Ohio
# 15       Fort Worth                 Texas
# 16        Charlotte        North Carolina
# 17          Seattle            Washington
# 18           Denver              Colorado
# 19          El Paso                 Texas
# 20          Detroit              Michigan
# 21       Washington  District of Columbia
# 22           Boston         Massachusetts
# 23          Memphis             Tennessee
# 24        Nashville             Tennessee
# 25         Portland                Oregon
# 26    Oklahoma City              Oklahoma
# 27        Las Vegas                Nevada
# 28        Baltimore              Maryland
# 29       Louisville              Kentucky
# ..              ...                   ...  ..  ..          ...
# 70           Toledo                  Ohio
# 71          Lincoln              Nebraska
# 72          Orlando               Florida
# 73      Chula Vista            California
# 74      Jersey City            New Jersey
# 75         Chandler               Arizona
# 76       Fort Wayne               Indiana
# 77          Buffalo              New York
# 78           Durham        North Carolina
# 79   St. Petersburg               Florida
# 80           Irvine            California
# 81           Laredo                 Texas
# 82          Lubbock                 Texas
# 83          Madison             Wisconsin
# 84          Gilbert               Arizona
# 85          Norfolk              Virginia
# 86             Reno                Nevada
# 87    Winston-Salem        North Carolina
# 88         Glendale               Arizona
# 89          Hialeah               Florida
# 90          Garland                 Texas
# 91       Scottsdale               Arizona
# 92           Irving                 Texas
# 93       Chesapeake              Virginia
# 94  North Las Vegas                Nevada
# 95          Fremont            California
# 96      Baton Rouge             Louisiana
# 97         Richmond              Virginia
# 98            Boise                 Idaho
# 99   San Bernardino            California
#
#    airport address airport rating        Lat         Lng  \
# 0                                  40.712775  -74.005973
# 1                                  34.052234 -118.243685
# 2                                  41.878114  -87.629798
# 3                                  29.760427  -95.369803
# 4                                  39.952584  -75.165222
# 5                                  33.448377 -112.074037
# 6                                  29.424122  -98.493628
# 7                                  32.715738 -117.161084
# 8                                  32.776664  -96.796988
# 9                                  37.338208 -121.886329
# 10                                 30.267153  -97.743061
# 11                                 30.332184  -81.655651
# 12                                 37.774929 -122.419415
# 13                                 39.768403  -86.158068
# 14                                 39.961176  -82.998794
# 15                                 32.755488  -97.330766
# 16                                 35.227087  -80.843127
# 17                                 47.606209 -122.332071
# 18                                 39.739236 -104.990251
# 19                                 31.761878 -106.485022
# 20                                 42.331427  -83.045754
# 21                                 38.907192  -77.036871
# 22                                 42.360082  -71.058880
# 23                                 35.149534  -90.048980
# 24                                 36.162664  -86.781602
# 25                                 45.512231 -122.658719
# 26                                 35.467560  -97.516428
# 27                                 36.169941 -115.139830
# 28                                 39.290385  -76.612189
# 29                                 38.252665  -85.758456
# ..             ...            ...        ...         ...
# 70                                 41.652805  -83.537867
# 71                                 40.813616  -96.702596
# 72                                 28.538335  -81.379237
# 73                                 32.640054 -117.084196
# 74                                 40.728157  -74.077642
# 75                                 33.306160 -111.841250
# 76                                 41.079273  -85.139351
# 77                                 42.886447  -78.878369
# 78                                 35.994033  -78.898619
# 79                                 27.767601  -82.640291
# 80                                 33.684567 -117.826505
# 81                                 27.503561  -99.507552
# 82                                 33.577863 -101.855166
# 83                                 43.073052  -89.401230
# 84                                 33.352826 -111.789027
# 6                     9800 Airport Blvd, San Antonio             4.0
# 7                        3225 N Harbor Dr, San Diego             3.9
# 8                      2400 Aviation Dr, DFW Airport             3.8
# 9                              1 Airport Dr, Oakland             3.8
# 10                    3600 Presidential Blvd, Austin             4.0
# 11              2400 Yankee Clipper Dr, Jacksonville             4.2
# 12                             1 Airport Dr, Oakland             3.8
# 13  7800 Col. H. Weir Cook Memorial Dr, Indianapolis             4.3
# 14              4600 International Gateway, Columbus             4.0
# 15                     2400 Aviation Dr, DFW Airport             3.8
# 16              5501 Josh Birmingham Pkwy, Charlotte             3.5
# 17                 17801 International Blvd, Seattle             3.7
# 18                            8500 Peña Blvd, Denver             4.0
# 19                          6701 Convair Rd, El Paso             4.3
# 20                                           Detroit             4.1
# 21                            1 Saarinen Cir, Dulles             3.9
# 22                           1 Harborside Dr, Boston             3.9
# 23                       2491 Winchester Rd, Memphis             3.6
# 24                          1 Terminal Dr, Nashville             4.1
# 25                     7000 NE Airport Way, Portland             4.5
# 26                   7100 Terminal Dr, Oklahoma City             4.1
# 27                 5757 Wayne Newton Blvd, Las Vegas             4.0
# 28                                         Baltimore             4.0
# 29                       600 Terminal Dr, Louisville             4.0
# ..                                               ...             ...
# 70             13336 Gildersleeve St, South Rockwood             0.0
# 71             12617 Weeping Water Rd, Weeping Water             5.0
# 72                        1 Jeff Fuqua Blvd, Orlando             3.7
# 73                       3225 N Harbor Dr, San Diego             3.9
# 74                             3 Brewster Rd, Newark             3.2
# 75                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 76                    3801 W Ferguson Rd, Fort Wayne             3.7
# 77                          4200 Genesee St, Buffalo             4.2
# 78              2400 John Brantley Blvd, Morrisville             4.2
# 79                    4100 George J Bean Pkwy, Tampa             4.4
# 80                                           Ontario             4.2
# 81                     5210 Bob Bullock Loop, Laredo             4.0
# 82                5401 N Martin L King Blvd, Lubbock             3.8
# 83                    4000 International Ln, Madison             4.2
# 84                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 85                         2200 Norview Ave, Norfolk             3.7
# 86                             2001 E Plumb Ln, Reno             4.1
# 87                 1000 Ted Johnson Pkwy, Greensboro             4.4
# 88                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 89                           2100 NW 42nd Ave, Miami             3.7
# 90                     2400 Aviation Dr, DFW Airport             3.8
# 91                   3400 E Sky Harbor Blvd, Phoenix             3.9
# 92                     2400 Aviation Dr, DFW Airport             3.8
# 93                         2200 Norview Ave, Norfolk             3.7
# 94                 5757 Wayne Newton Blvd, Las Vegas             4.0
# 95                             1 Airport Dr, Oakland             3.8
# 96               9430 Jackie Cochran Dr, Baton Rouge             3.9
# 97            1 Richard E Byrd Terminal Dr, Richmond             4.1
# 98                               County Rd 46, Boise             0.0
# 99                                           Ontario             4.2
#
# [100 rows x 12 columns]
